# %% [markdown]
# ## Hello World

# %%
print("Hello World!")

# %% [markdown]
# ## Repeating Yourself

# %%
for i in range(10):
    print(i)

# %%
for i in range(10):
    print(i*2)

# %%
for i in range(10):
    print(i**2)

# %% [markdown]
# ## Rotate Images

# %%
from PIL import Image
from IPython.display import display
image = Image.open("images/building.jpg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x675 at 0x1032EB630>

# %%
display(image.rotate(90))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x1032EB320>

# %%
display(image.rotate(270))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x1032EB6A0>

# %%
image.rotate(90).save('images/rotated/building.jpg')
